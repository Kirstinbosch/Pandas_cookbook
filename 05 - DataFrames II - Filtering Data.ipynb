# %% [markdown]
# # DataFrames II: Filtering Data

# %%
import pandas as pd

# %% [markdown]
# ## This Module's Dataset + Memory Optimization
# - The `pd.to_datetime` method converts a **Series** to hold datetime values.
# - The `format` parameter informs pandas of the format that the times are stored in.
# - We pass symbols designating the segments of the string. For example, %m means "month" and %d means day.
# - The `dt` attribute reveals an object with many datetime-related attributes and methods.
# - The `dt.time` attribute extracts only the time from each value in a datetime **Series**.
# - Use the `astype` method to convert the values in a **Series** to another type.
# - The `parse_dates` parameter of `read_csv` is an alternate way to parse strings as datetimes.

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 62.6+ KB

# %%
employees
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ..                ...                   ...
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [1000 rows x 8 columns]

# %%
employees["Start Date"] = pd.to_datetime(employees["Start Date"], format="%m/%d/%Y")

# %%
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p").dt.time

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 62.6+ KB

# %%
employees.head(10)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
# 5     Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 6       Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 7        NaN  Female 2015-07-20        10:43:00   45906   11.598
# 8     Angela  Female 2005-11-22        06:29:00   95570   18.523
# 9    Frances  Female 2002-08-08        06:51:00  139852    7.524
#
#   Senior Management                  Team
# 0              True             Marketing
# 1              True                   NaN
# 2             False               Finance
# 3              True               Finance
# 4              True       Client Services
# 5             False                 Legal
# 6              True               Product
# 7               NaN               Finance
# 8              True           Engineering
# 9              True  Business Development

# %%
employees["Senior Management"] = employees["Senior Management"].astype(bool)

# %%
employees["Gender"] = employees["Gender"].astype("category")

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 49.1+ KB

# %% [markdown]
# ## Filter A DataFrame  Based On A Condition
# - Pandas needs a **Series** of Booleans to perform a filter.
# - Pass the Boolean Series inside square brackets after the **DataFrame**.
# - We can generate a Boolean Series using a wide variety of operations (equality, inequality, less than, greater than, inclusion, etc)

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p").dt.time
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")

# %%
import datetime as dt

# %%
dt.time(12,0,0)
# Out:
# datetime.time(12, 0)

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 49.1+ KB

# %%
employees.head(5)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
employees[employees["Gender"] == "Male"]
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31        06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry   Male 1998-01-24        04:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18        01:35:00  115163   10.125
# ..         ...    ...        ...             ...     ...      ...
# 994     George   Male 2013-06-21        05:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert   Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [424 rows x 8 columns]

# %%
employees[employees["Team"] == "Finance"]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 7          NaN  Female 2015-07-20        10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14        07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28        10:47:00  114796    6.796
# ..         ...     ...        ...             ...     ...      ...
# 907  Elizabeth  Female 1998-07-27        11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19        04:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08        05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# 7                 True  Finance
# 14                True  Finance
# 46               False  Finance
# ..                 ...      ...
# 907              False  Finance
# 954               True  Finance
# 987               True  Finance
# 992               True  Finance
# 996              False  Finance
#
# [102 rows x 8 columns]

# %%
on_finance_team = employees["Team"] == "Finance"
employees[on_finance_team]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 7          NaN  Female 2015-07-20        10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14        07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28        10:47:00  114796    6.796
# ..         ...     ...        ...             ...     ...      ...
# 907  Elizabeth  Female 1998-07-27        11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19        04:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08        05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# 7                 True  Finance
# 14                True  Finance
# 46               False  Finance
# ..                 ...      ...
# 907              False  Finance
# 954               True  Finance
# 987               True  Finance
# 992               True  Finance
# 996              False  Finance
#
# [102 rows x 8 columns]

# %%
employees[employees["Senior Management"] == True]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# ..         ...     ...        ...             ...     ...      ...
# 991       Rose  Female 2002-08-25        05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15        03:53:00   56450   19.040
# 994     George    Male 2013-06-21        05:47:00   98874    4.479
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 1                 True              NaN
# 3                 True          Finance
# 4                 True  Client Services
# 6                 True          Product
# ..                 ...              ...
# 991               True        Marketing
# 992               True          Finance
# 993               True      Engineering
# 994               True        Marketing
# 999               True            Sales
#
# [535 rows x 8 columns]

# %%
employees[employees["Salary"] > 110000]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 9      Frances  Female 2002-08-08        06:51:00  139852    7.524
# 12     Brandon    Male 1980-12-01        01:08:00  112807   17.492
# ..         ...     ...        ...             ...     ...      ...
# 987     Gloria  Female 2014-12-08        05:08:00  136709   10.331
# 991       Rose  Female 2002-08-25        05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 2                False               Finance
# 3                 True               Finance
# 5                False                 Legal
# 9                 True  Business Development
# 12                True       Human Resources
# ..                 ...                   ...
# 987               True               Finance
# 991               True             Marketing
# 992               True               Finance
# 995              False          Distribution
# 999               True                 Sales
#
# [322 rows x 8 columns]

# %%
employees[employees["Bonus %"] < 1.5]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# 15     Lillian  Female 2016-06-05        06:09:00   59414    1.256
# 58     Theresa  Female 2010-04-11        07:18:00   72670    1.481
# 77     Charles    Male 2004-09-14        08:13:00  107391    1.260
# 175     Willie    Male 1998-02-17        08:20:00  146651    1.451
# 189   Clarence    Male 1998-05-02        03:16:00   85700    1.215
# 217    Douglas    Male 1999-09-03        04:00:00   83341    1.015
# 273   Nicholas    Male 1994-04-12        08:21:00   74669    1.113
# 279       Ruby  Female 2000-11-08        07:35:00  105946    1.139
# 365     Gloria     NaN 1983-07-19        01:57:00  140885    1.113
# 445      Chris    Male 2006-12-12        01:57:00   71642    1.496
# 481        NaN  Female 2013-04-27        06:40:00   93847    1.085
# 527      Helen     NaN 1993-12-02        01:42:00   45724    1.022
# 570      Kelly  Female 1996-08-16        03:09:00   41427    1.431
# 578     Amanda  Female 1982-03-17        11:46:00  107111    1.438
# 579     Harold    Male 2010-10-18        08:45:00   65673    1.187
# 617      Kathy  Female 2001-01-14        05:11:00   45682    1.451
# 618      Peter    Male 1992-11-24        05:43:00   69297    1.268
# 638    Frances  Female 1996-11-12        06:08:00  112467    1.433
# 652     Willie    Male 2009-12-05        05:39:00  141932    1.017
# 708      Steve    Male 2002-01-11        09:17:00   51821    1.197
# 732      Henry    Male 1986-05-12        02:04:00   59943    1.432
# 734        NaN  Female 1994-12-18        08:42:00  138807    1.400
# 746     Gloria  Female 2004-08-19        10:31:00   46602    1.027
# 912        Joe    Male 1998-12-08        10:28:00  126120    1.020
# 929    Theresa  Female 2001-04-27        09:17:00   75661    1.079
# 954        Joe    Male 1980-01-19        04:06:00  119667    1.148
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
#
#      Senior Management                  Team
# 4                 True       Client Services
# 15               False               Product
# 58                True           Engineering
# 77                True             Marketing
# 175               True           Engineering
# 189              False                 Sales
# 217               True       Client Services
# 273               True               Product
# 279              False  Business Development
# 365              False       Human Resources
# 445              False                   NaN
# 481               True  Business Development
# 527              False               Product
# 570              False               Product
# 578               True               Product
# 579               True                 Legal
# 617               True             Marketing
# 618              False               Finance
# 638              False  Business Development
# 652               True           Engineering
# 708               True                 Legal
# 732              False               Finance
# 734               True       Human Resources
# 746               True  Business Development
# 912              False                   NaN
# 929               True                 Legal
# 954               True               Finance
# 997              False               Product

# %%
employees[employees["Start Date"] < "1985-01-01"]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 10      Louise  Female 1980-08-12        09:01:00   63241   15.132
# 12     Brandon    Male 1980-12-01        01:08:00  112807   17.492
# 18       Diana  Female 1981-10-23        10:27:00  132940   19.082
# 28       Terry    Male 1981-11-27        06:30:00  124008   13.464
# 37       Linda  Female 1981-10-19        08:49:00   57427    9.557
# ..         ...     ...        ...             ...     ...      ...
# 982       Rose  Female 1982-04-06        10:43:00   91411    8.639
# 983       John    Male 1982-12-23        10:35:00  146907   11.738
# 985    Stephen     NaN 1983-07-10        08:10:00   85668    1.909
# 986      Donna  Female 1982-11-26        07:04:00   82871   17.999
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
#
#      Senior Management             Team
# 10                True              NaN
# 12                True  Human Resources
# 18               False  Client Services
# 28                True  Client Services
# 37                True  Client Services
# ..                 ...              ...
# 982               True  Human Resources
# 983              False      Engineering
# 985              False            Legal
# 986              False        Marketing
# 996              False          Finance
#
# [133 rows x 8 columns]

# %%
employees["Last Login Time"] = employees["Last Login Time"]  < dt.time(12,0,0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 employees["Last Login Time"] = employees["Last Login Time"]  < dt.time(12,0,0)
#
# File ~/PycharmProjects/pandas_cookbook/.venv/lib/python3.9/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/PycharmProjects/pandas_cookbook/.venv/lib/python3.9/site-packages/pandas/core/arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File ~/PycharmProjects/pandas_cookbook/.venv/lib/python3.9/site-packages/pandas/core/series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6121 return self._construct_result(res_values, name=res_name)
#
# File ~/PycharmProjects/pandas_cookbook/.venv/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:347, in comparison_op(left, right, op)
#     344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
# --> 347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#     349 return res_values
#
# File ~/PycharmProjects/pandas_cookbook/.venv/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     215     func = partial(expressions.evaluate, op)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)
#     225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
#
# File ~/PycharmProjects/pandas_cookbook/.venv/lib/python3.9/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     239 if op_str is not None:
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~/PycharmProjects/pandas_cookbook/.venv/lib/python3.9/site-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      71 if _TEST_MODE:
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: '<' not supported between instances of 'bool' and 'datetime.time'

# %% [markdown]
# ## Filter with More than One Condition (AND)
# - Add the `&` operator in between two Boolean **Series** to filter by multiple conditions.
# - We can assign the **Series** to variables to make the syntax more readable.

# %%
import datetime as dt
dt.time(12,0,0)
# Out:
# datetime.time(12, 0)

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p")
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")

# %%
is_female = employees["Gender"] == "Female"
is_in_marketing = employees["Team"] == "Marketing"
salary_over_100k = employees["Salary"] > 100000

# %%
employees[is_female & is_in_marketing & salary_over_100k]
# Out:
#      First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 98         Tina  Female 2016-06-16 1900-01-01 07:47:00  100705   16.961
# 140     Shirley  Female 1981-02-28 1900-01-01 01:23:00  113850    1.854
# 158       Norma  Female 1999-02-28 1900-01-01 08:45:00  114412    8.756
# 305    Margaret  Female 1993-02-06 1900-01-01 01:05:00  125220    3.733
# 319  Jacqueline  Female 1981-11-25 1900-01-01 03:01:00  145988   18.243
# 379         NaN  Female 2002-09-18 1900-01-01 12:39:00  118906    4.537
# 468      Janice  Female 1997-06-28 1900-01-01 01:48:00  136032   10.696
# 490      Judith  Female 2007-11-23 1900-01-01 01:22:00  117055    7.461
# 531    Virginia  Female 2010-05-02 1900-01-01 09:10:00  123649   10.154
# 585     Shirley  Female 1988-04-16 1900-01-01 11:09:00  132156    2.754
# 627        Anne  Female 1984-11-21 1900-01-01 12:30:00  128305   16.636
# 656        Lisa  Female 1982-02-09 1900-01-01 06:44:00  113592   17.108
# 675       Diane  Female 2009-10-30 1900-01-01 06:56:00  130577   12.791
# 676       Annie  Female 1992-06-06 1900-01-01 10:04:00  138925    9.801
# 811      Judith  Female 1989-09-03 1900-01-01 11:16:00  134048    6.818
# 813      Evelyn  Female 2002-02-10 1900-01-01 04:44:00  123621   19.767
# 881        Ruby  Female 1980-01-28 1900-01-01 11:08:00  142868    6.318
# 991        Rose  Female 2002-08-25 1900-01-01 05:12:00  134505   11.051
#
#      Senior Management       Team
# 98                True  Marketing
# 140              False  Marketing
# 158               True  Marketing
# 305              False  Marketing
# 319              False  Marketing
# 379               True  Marketing
# 468               True  Marketing
# 490              False  Marketing
# 531               True  Marketing
# 585              False  Marketing
# 627              False  Marketing
# 656               True  Marketing
# 675              False  Marketing
# 676               True  Marketing
# 811               True  Marketing
# 813               True  Marketing
# 881              False  Marketing
# 991               True  Marketing

# %% [markdown]
# ## Filter with More than One Condition (OR)
# - Use the `|` operator in between two Boolean **Series** to filter by *either* condition.

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p")
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")

# %%
is_senior_management = employees["Senior Management"] == True
started_in_80s = employees["Start Date"] < "1990-01-01"
employees[is_senior_management | started_in_80s]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 1900-01-01 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 1900-01-01 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 1900-01-01 01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 1900-01-01 04:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 1900-01-01 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 992    Anthony    Male 2011-10-16 1900-01-01 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 1900-01-01 03:53:00   56450   19.040
# 994     George    Male 2013-06-21 1900-01-01 05:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 1900-01-01 06:30:00   42392   19.675
# 999     Albert    Male 2012-05-15 1900-01-01 06:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 1                 True              NaN
# 3                 True          Finance
# 4                 True  Client Services
# 5                False            Legal
# ..                 ...              ...
# 992               True          Finance
# 993               True      Engineering
# 994               True        Marketing
# 996              False          Finance
# 999               True            Sales
#
# [653 rows x 8 columns]

# %% [markdown]
# ## The isin Method
# - The `isin` **Series** method accepts a collection object like a list, tuple, or **Series**.
# - The method returns True for a row if its value is found in the collection.

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p")
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")

# %%
target_teams = employees["Team"].isin(["Legal", "Sales", "Product"])
employees[target_teams]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 1900-01-01 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 1900-01-01 04:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 1900-01-01 03:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 1900-01-01 11:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 1900-01-01 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 1900-01-01 05:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 1900-01-01 08:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 1900-01-01 04:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 1900-01-01 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 1900-01-01 06:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# 11                True    Legal
# 13               False    Sales
# 15               False  Product
# ..                 ...      ...
# 981              False    Legal
# 985              False    Legal
# 989              False    Legal
# 997              False  Product
# 999               True    Sales
#
# [277 rows x 8 columns]

# %% [markdown]
# ## The isnull and notnull Methods
# - The `isnull` method returns True for `NaN` values in a **Series**.
# - The `notnull` method returns True for present values in a **Series**.

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p")
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")

# %%
employees[employees["Team"].isnull()]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 1900-01-01 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 1900-01-01 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 1900-01-01 04:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 1900-01-01 02:27:00  122340    6.417
# 91         James     NaN 2005-01-26 1900-01-01 11:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 1900-01-01 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 1900-01-01 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 1900-01-01 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 1900-01-01 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 1900-01-01 06:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 1900-01-01 05:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 1900-01-01 06:06:00   66067   10.957
# 382          NaN  Female 1996-04-18 1900-01-01 03:57:00  107024   12.182
# 434        Joyce  Female 1995-02-07 1900-01-01 07:38:00   50701   14.227
# 438        Jason    Male 1998-11-20 1900-01-01 02:54:00   69244    6.220
# 445        Chris    Male 2006-12-12 1900-01-01 01:57:00   71642    1.496
# 479      Richard    Male 1997-07-04 1900-01-01 11:47:00   47647   18.787
# 512        Wanda  Female 1993-04-06 1900-01-01 03:11:00   78883   19.695
# 513        Jimmy    Male 2013-11-19 1900-01-01 07:29:00   63549   19.624
# 520        Peter    Male 2003-02-22 1900-01-01 09:09:00   56580    8.411
# 567          NaN  Female 1980-04-01 1900-01-01 08:04:00   48141   12.605
# 573     Kimberly  Female 1981-12-30 1900-01-01 04:51:00   81800    5.435
# 580        Harry    Male 1985-01-27 1900-01-01 08:18:00   65482   18.089
# 626          NaN  Female 1997-04-13 1900-01-01 08:03:00  131755    2.930
# 634         Carl    Male 1987-03-30 1900-01-01 05:59:00   75598   19.289
# 635        Randy    Male 2000-09-27 1900-01-01 03:04:00   89831   13.047
# 647       Donald    Male 1988-04-06 1900-01-01 10:00:00  122920    5.320
# 669       Joseph     NaN 1982-03-28 1900-01-01 01:05:00   86564   11.879
# 684        Alice  Female 2016-01-21 1900-01-01 05:07:00  117787   10.485
# 706         Todd    Male 1993-07-04 1900-01-01 06:53:00  128175   18.473
# 726       Daniel    Male 2016-02-29 1900-01-01 04:04:00   77287   13.000
# 753      Antonio    Male 1999-06-06 1900-01-01 10:54:00   41928    5.478
# 774          NaN  Female 2000-06-18 1900-01-01 07:36:00  106428   10.867
# 781     Lawrence    Male 1995-07-03 1900-01-01 10:55:00   46378    9.127
# 794       Nicole  Female 2004-03-01 1900-01-01 05:17:00   44021   10.286
# 826          NaN     NaN 1988-08-01 1900-01-01 01:35:00   87103    5.665
# 850      Charles    Male 1997-09-03 1900-01-01 10:04:00  148291    6.002
# 851        Bobby    Male 1996-08-19 1900-01-01 01:16:00  147842   16.158
# 853      Mildred  Female 2007-04-06 1900-01-01 10:06:00  139284   11.390
# 855      Phillip     NaN 2003-10-20 1900-01-01 11:09:00   89700    2.277
# 864         Ryan    Male 2012-11-16 1900-01-01 01:47:00   57292    6.010
# 912          Joe    Male 1998-12-08 1900-01-01 10:28:00  126120    1.020
# 951          NaN  Female 2010-09-14 1900-01-01 05:19:00  143638    9.662
#
#      Senior Management Team
# 1                 True  NaN
# 10                True  NaN
# 23                True  NaN
# 32                True  NaN
# 91               False  NaN
# 109              False  NaN
# 139               True  NaN
# 199               True  NaN
# 258              False  NaN
# 290               True  NaN
# 314              False  NaN
# 367               True  NaN
# 382               True  NaN
# 434               True  NaN
# 438               True  NaN
# 445              False  NaN
# 479               True  NaN
# 512              False  NaN
# 513              False  NaN
# 520               True  NaN
# 567               True  NaN
# 573               True  NaN
# 580              False  NaN
# 626               True  NaN
# 634              False  NaN
# 635               True  NaN
# 647              False  NaN
# 669               True  NaN
# 684              False  NaN
# 706               True  NaN
# 726               True  NaN
# 753               True  NaN
# 774               True  NaN
# 781              False  NaN
# 794              False  NaN
# 826               True  NaN
# 850              False  NaN
# 851               True  NaN
# 853               True  NaN
# 855               True  NaN
# 864              False  NaN
# 912              False  NaN
# 951               True  NaN

# %%
employees[employees["Team"].notnull()]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 1900-01-01 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 1900-01-01 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 1900-01-01 01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 1900-01-01 04:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 1900-01-01 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 1900-01-01 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 1900-01-01 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 1900-01-01 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 1900-01-01 04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 1900-01-01 06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [957 rows x 8 columns]

# %%
employees["First Name"].isnull().sum()
# Out:
# np.int64(67)

# %% [markdown]
# ## The between Method
# - The `between` method returns True if a **Series** value is found within its range.

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p")
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")

# %%
employees[employees["Salary"].between(60000, 70000)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 1900-01-01 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 1900-01-01 04:20:00   65476   10.012
# 10      Louise  Female 1980-08-12 1900-01-01 09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22 1900-01-01 07:18:00   64714    4.934
# 41   Christine     NaN 2015-06-28 1900-01-01 01:08:00   66582   11.308
# ..         ...     ...        ...                 ...     ...      ...
# 965  Catherine  Female 1989-09-25 1900-01-01 01:31:00   68164   18.393
# 970      Alice  Female 1988-09-03 1900-01-01 08:54:00   63571   15.397
# 974      Harry    Male 2011-08-30 1900-01-01 06:31:00   67656   16.455
# 978       Sean    Male 1983-01-17 1900-01-01 02:23:00   66146   11.178
# 998      Larry    Male 2013-04-20 1900-01-01 04:45:00   60500   11.985
#
#      Senior Management                  Team
# 1                 True                   NaN
# 6                 True               Product
# 10                True                   NaN
# 20                True                 Legal
# 41                True  Business Development
# ..                 ...                   ...
# 965              False       Client Services
# 970               True               Product
# 974               True       Client Services
# 978              False       Human Resources
# 998              False  Business Development
#
# [86 rows x 8 columns]

# %% [markdown]
# ## The duplicated Method
# - The `duplicated` method returns True if a **Series** value is a duplicate.
# - Pandas will mark one occurrence of a repeated value as a non-duplicate.
# - Use the `keep` parameter to designate whether the first or last occurrence of a repeated value should be considered the "non-duplicate".
# - Pass False to the `keep` parameter to mark all occurrences of repeated values as duplicates.
# - Use the tilde symbol (`~`) to invert a **Series's** values. Trues will become Falses, and Falses will become trues.

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p")
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")

# %%
employees[employees["First Name"].duplicated()]
employees[employees["First Name"].duplicated(keep="first")]
employees[employees["First Name"].duplicated(keep="last")]
employees[employees["First Name"].duplicated(keep=False)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 1900-01-01 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 1900-01-01 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 1900-01-01 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 1900-01-01 01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 1900-01-01 04:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 959     Albert    Male 1992-09-19 1900-01-01 02:35:00   45094    5.850
# 960    Stephen    Male 1989-10-29 1900-01-01 11:34:00   93997   18.093
# 970      Alice  Female 1988-09-03 1900-01-01 08:54:00   63571   15.397
# 973    Russell    Male 2013-05-10 1900-01-01 11:08:00  137359   11.105
# 982       Rose  Female 1982-04-06 1900-01-01 10:43:00   91411    8.639
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 959               True  Business Development
# 960               True  Business Development
# 970               True               Product
# 973              False  Business Development
# 982               True       Human Resources
#
# [799 rows x 8 columns]

# %%
employees[~employees["First Name"].duplicated(keep=False)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 1900-01-01 01:35:00  115163   10.125
# 8       Angela  Female 2005-11-22 1900-01-01 06:29:00   95570   18.523
# 33        Jean  Female 1993-12-18 1900-01-01 09:07:00  119082   16.180
# 190      Carol  Female 1996-03-19 1900-01-01 03:39:00   57783    9.129
# 291      Tammy  Female 1984-11-11 1900-01-01 10:30:00  132839   17.463
# 495     Eugene    Male 1984-05-24 1900-01-01 10:54:00   81077    2.117
# 688      Brian    Male 2007-04-07 1900-01-01 10:47:00   93901   17.821
# 832      Keith    Male 2003-02-12 1900-01-01 03:02:00  120672   19.467
# 887      David    Male 2009-12-05 1900-01-01 08:48:00   92242   15.407
#
#      Senior Management                  Team
# 5                False                 Legal
# 8                 True           Engineering
# 33               False  Business Development
# 190              False               Finance
# 291               True       Client Services
# 495              False                 Sales
# 688               True                 Legal
# 832              False                 Legal
# 887              False                 Legal

# %% [markdown]
# ## The drop_duplicates Method
# - The `drop_duplicates` method deletes rows with duplicate values.
# - By default, it will remove a row if *all* of its values are shared with another row.
# - The `subset` parameter configures the columns to look for duplicate values within.
# - Pass a list to `subset` parameter to look for duplicates across multiple columns.

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p")
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")

# %%
employees.drop_duplicates()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 1900-01-01 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 1900-01-01 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 1900-01-01 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 1900-01-01 01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 1900-01-01 04:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 1900-01-01 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 1900-01-01 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 1900-01-01 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 1900-01-01 04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 1900-01-01 06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %%
employees.drop_duplicates("Team", keep="last")
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 951        NaN  Female 2010-09-14 1900-01-01 05:19:00  143638    9.662
# 988      Alice  Female 2004-10-05 1900-01-01 09:34:00   47638   11.209
# 989     Justin     NaN 1991-02-10 1900-01-01 04:58:00   38344    3.794
# 990      Robin  Female 1987-07-24 1900-01-01 01:35:00  100765   10.982
# 993       Tina  Female 1997-05-15 1900-01-01 03:53:00   56450   19.040
# 994     George    Male 2013-06-21 1900-01-01 05:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 1900-01-01 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 1900-01-01 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 1900-01-01 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 1900-01-01 04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 1900-01-01 06:24:00  129949   10.169
#
#      Senior Management                  Team
# 951               True                   NaN
# 988              False       Human Resources
# 989              False                 Legal
# 990               True       Client Services
# 993               True           Engineering
# 994               True             Marketing
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales

# %%
employees.drop_duplicates(["Senior Management", "Team"]).sort_values("Team")
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 33       Jean  Female 1993-12-18 1900-01-01 09:07:00  119082   16.180
# 9     Frances  Female 2002-08-08 1900-01-01 06:51:00  139852    7.524
# 4       Larry    Male 1998-01-24 1900-01-01 04:47:00  101004    1.389
# 18      Diana  Female 1981-10-23 1900-01-01 10:27:00  132940   19.082
# 60      Paula     NaN 2005-11-23 1900-01-01 02:01:00   48866    4.271
# 40    Michael    Male 2008-10-10 1900-01-01 11:25:00   99283    2.665
# 8      Angela  Female 2005-11-22 1900-01-01 06:29:00   95570   18.523
# 54       Sara  Female 2007-08-15 1900-01-01 09:23:00   83677    8.999
# 2       Maria  Female 1993-04-23 1900-01-01 11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04 1900-01-01 01:00:00  138705    9.340
# 16     Jeremy    Male 2010-09-21 1900-01-01 05:56:00   90370    7.369
# 12    Brandon    Male 1980-12-01 1900-01-01 01:08:00  112807   17.492
# 11      Julie  Female 1997-10-26 1900-01-01 03:19:00  102508   12.637
# 5      Dennis    Male 1987-04-18 1900-01-01 01:35:00  115163   10.125
# 21    Matthew    Male 1995-09-05 1900-01-01 02:12:00  100612   13.645
# 0     Douglas    Male 1993-08-06 1900-01-01 12:42:00   97308    6.945
# 6        Ruby  Female 1987-08-17 1900-01-01 04:20:00   65476   10.012
# 15    Lillian  Female 2016-06-05 1900-01-01 06:09:00   59414    1.256
# 13       Gary    Male 2008-01-27 1900-01-01 11:40:00  109831    5.831
# 45      Roger    Male 1980-04-17 1900-01-01 11:32:00   88010   13.886
# 1      Thomas    Male 1996-03-31 1900-01-01 06:53:00   61933    4.170
# 91      James     NaN 2005-01-26 1900-01-01 11:00:00  128771    8.309
#
#     Senior Management                  Team
# 33              False  Business Development
# 9                True  Business Development
# 4                True       Client Services
# 18              False       Client Services
# 60              False          Distribution
# 40               True          Distribution
# 8                True           Engineering
# 54              False           Engineering
# 2               False               Finance
# 3                True               Finance
# 16              False       Human Resources
# 12               True       Human Resources
# 11               True                 Legal
# 5               False                 Legal
# 21              False             Marketing
# 0                True             Marketing
# 6                True               Product
# 15              False               Product
# 13              False                 Sales
# 45               True                 Sales
# 1                True                   NaN
# 91              False                   NaN

# %% [markdown]
# ## The unique and nunique Methods
# - The `unique` method on a **Series** returns a collection of its unique values. The method does not exist on a **DataFrame**.
# - The `nunique` method returns a *count* of the number of unique values in the **Series**/**DataFrame**.
# - The `dropna` parameter configures whether to include or exclude missing (`NaN`) values.

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p")
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")

# %%
type(employees["Gender"].unique())
# Out:
# pandas.core.arrays.categorical.Categorical

# %%
employees["Team"].nunique()
# Out:
# 10
